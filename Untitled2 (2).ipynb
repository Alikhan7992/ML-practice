# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
home_loan = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")

# %%
home_loan
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
home_loan.shape
# Out:
# (506, 14)

# %%
input_data = home_loan.iloc[:,:-1]
output_data = home_loan['medv']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(input_data,output_data,test_size=0.25,random_state=40)

# %%
x_test.shape
# Out:
# (127, 13)

# %%
x_train.shape
# Out:
# (379, 13)

# %%
x_train.shape , y_train.shape
# Out:
# ((379, 13), (379,))

# %%
x_test.shape,y_test.shape
# Out:
# ((127, 13), (127,))

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (379, 13)
# (127, 13)
# (379,)
# (127,)

# %% [markdown]
# # Linear regression

# %%
salary_data = pd.read_csv(r'SalaryData.csv')

# %%
salary_data.head(3)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x='YearsExperience', y='Salary', data = salary_data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
x = salary_data[['YearsExperience']]
y = salary_data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(input_data,output_data,test_size=0.20,random_state=40)
